# %%
import pickle

with open('data_splits/recon/test/time.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
print(data)
# Out:
# <class 'list'>
# ...

# %%
with open('data_splits/recon/test/rollout.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
print(data)
# Out:
# <class 'list'>
# ...

# %%
with open('data_splits/recon/test/navigation_eval.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
print(data)
# Out:
# <class 'list'>
# ...

# %%
with open('data_splits/airvln/test/dataset_dist_8_to_8_n4_len_traj_pred_8.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
print(len(data[0]))
print(data)
# Out:
# <class 'tuple'>
# 156
# ...
